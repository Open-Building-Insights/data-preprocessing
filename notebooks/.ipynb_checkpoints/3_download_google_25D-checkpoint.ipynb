# %% [markdown]
# ### 3. Downloading google height raster

# %% [markdown]
# This notebook will iterate thorugh a plain text file obtained from [Google Colab](https://colab.research.google.com/github/google-research/google-research/blob/master/building_detection/open_buildings_temporal_download_region_geotiffs.ipynb) to download geotiff files containing estimates of height.

# %% [markdown]
# ### Initial configuration
#
#     config_str = """{"COS_ENDPOINT_URL": "https://s3.direct.eu-de.cloud-object-storage.appdomain.cloud",
#     "COUNTRY_NAME": "India",
#     "FILE_PREFIX": "Patan",
#     "VIDA_PARQUET_BUCKET": "parquets",
#     "VIDA_S2_PARTITIONS": "onboarding-bucket-j",
#     "COS_AUTH_ENDPOINT_URL":"https://iam.cloud.ibm.com/oidc/token",
#     "COS_APIKEY": "xxx",
#     "UTILS_BUCKET": "notebook-utils-bucket",
#     "VIDA_COUNTRIES_BUILDINGS": "onboarding-bucket-j"}"""
#
# * `COS_ENDPOINT_URL`: The S3 API endpoint for your IBM COS instance.
# * `FILE_PREFIX`: Region of study. Geotif files are name after this parameter plus the original name.
# * `COUNTRY_NAME`: Defines the target country to filter the google dataset.
# * `VIDA_PARQUET_BUCKET`: The name of the source bucket where the Parquet files are stored.
# * `COS_AUTH_ENDPOINT_URL`: The authentication endpoint for generating IBM IAM tokens.
# * `COS_APIKEY`: Your unique IBM Cloud API key for programmatic access.
# * `UTILS_BUCKET`: Where the .py file to download the package `filtering_grid_generator`.
# * `VIDA_COUNTRIES_BUILDINGS`: Bucket to upload results.

# %%
# Import necessary libraries
import rasterio
import matplotlib.pyplot as plt
from PIL import Image
import zipfile
import os
import ibm_boto3
from botocore.client import Config
import boto3
import requests
from botocore.exceptions import NoCredentialsError
import os
import geopandas as gpd
from datetime import datetime

# %%
# Read notebook configuration
import getpass
import json

#config_str = getpass.getpass('Enter your prepared config: ')
config = json.loads(config_str)

# %%
datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2025-10-02 13:57:09'

# %% [markdown]
# This notebook requires as first step to download a plain text from [Google Colab](https://colab.research.google.com/github/google-research/google-research/blob/master/building_detection/open_buildings_temporal_download_region_geotiffs.ipynb). The plain text will contain a list of URL to download the Geotiffs where we want to download to compute the heights of the buildings.
# As 2025, the available granular information (at 10 meters resolution) is from 2023 and it requires as input WKT (Well-Known-Text) format, you can obtain the WKT by:
# * Using this [sanbox](https://arthur-e.github.io/Wicket/sandbox-gmaps3.html). You can draw an aproximation of the study area and generate the WKT on the fly.
# * Excecuting the next cell, where you will use the relative path to the geojson file and get a .txt where you can copz the WKT, if you decide for the first approach.

# %%
input_file = "/home/julian/notebooks/handover/notebooks/district_boundaries/Patan.geojson"
output_folder = "/home/julian/notebooks/"

# %%
geojson_read = gpd.read_file(input_file)
geojson_read['wkt_geometry'] = geojson_read['geometry'].to_wkt()
path_wkt=os.path.join(output_folder, "wkt.txt")
with open(path_wkt, "w") as f:
    for wkt in geojson_read.geometry.to_wkt():
        f.write(wkt + '\n')
        print(f"WKT created in the following path: {output_folder}")
# Out:
# WKT created in the following path: /home/julian/notebooks/

# %% [markdown]
# The path indicates where the .txt is located:

# %%
text_file_path = "/home/julian/notebooks/downloadable_urls.txt"

# %% [markdown]
# This code initializes a client object to securely connect to IBM Cloud Object Storage (COS). This client, stored in the cos_client variable, acts as the primary interface for all subsequent interactions with the storage service, such as uploading or downloading files.

# %%
cos_client = ibm_boto3.client(service_name='s3',
                                  ibm_api_key_id=config["COS_APIKEY"],
                                  ibm_auth_endpoint=config["COS_AUTH_ENDPOINT_URL"],
                                  config=Config(signature_version='oauth'),
                                  endpoint_url=config["COS_ENDPOINT_URL"])

# %% [markdown]
# The following functions automates downloading GeoTIFF files from a list of URLs, uploading them to IBM Cloud Object Storage (COS), and then deleting the local copies. It's designed to transfer files from a public source to the cloud storage.

# %%
file_prefix = config["FILE_PREFIX"]
bucket_name = config["BUCKET_TIFF"]
download_directory = "/tmp/geotiffs"  # Temporary local directory for downloads

# Step 1: Download GeoTIFF files
def download_geotiff(url, output_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise exception for HTTP errors
        with open(output_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {output_path}")
    except Exception as e:
        print(f"Error downloading {url}: {e}")

# Step 2: Upload GeoTIFF to COS
def upload_to_cos(local_path, bucket, object_key):
    try:
        cos_client.upload_file(local_path, bucket, object_key)
        print(f"Uploaded {local_path} to COS as {object_key}")
    except NoCredentialsError:
        print("Credentials not available.")
    except Exception as e:
        print(f"Error uploading {local_path} to COS: {e}")

# Step 3: Main process
def process_geotiff_files():
   
    # Create a temporary local directory for downloads
    os.makedirs(download_directory, exist_ok=True)
    
    with open(text_file_path,'r') as url_list:
        for url in url_list:
            filename = url.split('/')[-1]  # Extract the filename from URL
            filename = filename.strip()

            url = url.replace("gs://", "https://storage.googleapis.com/")
            url = url.strip()
             
            local_path = os.path.join(download_directory, filename)
            
            #object_key = f"file_prefix{filename}"  # Path in the COS bucket
            object_key = f"{file_prefix}_{filename}"  # Path in the COS bucket
        
            # Download the file
            download_geotiff(url, local_path)
            print(f"url: {url}")
            print(f"filename: {filename}")
            print(f"Local path: {local_path}")
            print(f"Object key: {object_key}")
        
            # Upload the file to COS
            upload_to_cos(local_path, bucket_name, object_key)
        
            # Cleanup local file
            os.remove(local_path)

# Run the script
if __name__ == "__main__":
    process_geotiff_files()
# Out:
# Downloaded: /tmp/geotiffs/tile_u84WWA1lmU4.tif
# url: https://storage.googleapis.com/open-buildings-temporal-data/v1/geotiffs/395b4_2023_06_30/tile_u84WWA1lmU4.tif
# filename: tile_u84WWA1lmU4.tif
# Local path: /tmp/geotiffs/tile_u84WWA1lmU4.tif
# Object key: Patan_tile_u84WWA1lmU4.tif
# Uploaded /tmp/geotiffs/tile_u84WWA1lmU4.tif to COS as Patan_tile_u84WWA1lmU4.tif
# Downloaded: /tmp/geotiffs/tile_wPUp7W2tjh4.tif
# url: https://storage.googleapis.com/open-buildings-temporal-data/v1/geotiffs/395b4_2023_06_30/tile_wPUp7W2tjh4.tif
# filename: tile_wPUp7W2tjh4.tif
# Local path: /tmp/geotiffs/tile_wPUp7W2tjh4.tif
# Object key: Patan_tile_wPUp7W2tjh4.tif
# Uploaded /tmp/geotiffs/tile_wPUp7W2tjh4.tif to COS as Patan_tile_wPUp7W2tjh4.tif
# Downloaded: /tmp/geotiffs/tile_k-oAw7v0Zng.tif
# url: https://storage.googleapis.com/open-buildings-temporal-data/v1/geotiffs/395b4_2023_06_30/tile_k-oAw7v0Zng.tif
# filename: tile_k-oAw7v0Zng.tif
# Local path: /tmp/geotiffs/tile_k-oAw7v0Zng.tif
# ...

# %%
datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2025-10-02 13:59:42'
