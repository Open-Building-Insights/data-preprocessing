# %%
# Import necessary libraries
#import rasterio
import matplotlib.pyplot as plt
from PIL import Image
import zipfile
import os
from botocore.client import Config
import boto3
import requests
from botocore.exceptions import NoCredentialsError
import os
import geopandas as gpd
from datetime import datetime
import tkinter as tk
from tkinter import filedialog, messagebox

# %%
datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %% [markdown]
# This notebook requires as first step to download a plain text from [Google Colab](https://colab.research.google.com/github/google-research/google-research/blob/master/building_detection/open_buildings_temporal_download_region_geotiffs.ipynb). The plain text will contain a list of URL to download the Geotiffs where we want to download to compute the heights of the buildings.
# As 2025, the available granular information (at 10 meters resolution) is from 2023 and it requires as input WKT (Well-Known-Text) format, you can obtain the WKT by:
# * Using this [sanbox](https://arthur-e.github.io/Wicket/sandbox-gmaps3.html). You can draw an aproximation of the study area and generate the WKT on the fly.
# * Excecuting the next cell, where you will upload the geojson file from previous nextbooks and get a .txt where you can get the WKT, if you decide for the first approach, you can skip the next step. If not, the next code ask for two inputs, the location of the geospatile file and a folder where to store a plain text, which will contain the informatino of the WKT

# %%
root = tk.Tk()
root.withdraw()
root.attributes("-topmost", True)
messagebox.showinfo('Open Buildings Insights', 'Open the input file with the administrative boundaries')
input_file = filedialog.askopenfilename()
messagebox.showinfo('Open Buildings Insights', 'Browse to the folder where you want to save the WKT in .txt format')
path_wkt = filedialog.askdirectory()
geojson_read = gpd.read_file(input_file)
geojson_read['wkt_geometry'] = geojson_read['geometry'].to_wkt()
path_wkt=os.path.join(path_wkt, "wkt.txt")
with open(path_wkt, "w") as f:
    for wkt in geojson_read.geometry.to_wkt():
        f.write(wkt + '\n')
        print(f"WKT created in the following path: {path_wkt}")

# %% [markdown]
# Run the Google Colab, you should obtain a file with URLs like this:
# * *gs://open-buildings-temporal-data/v1/geotiffs/3be7c_2023_06_30/tile_uhCUB-kvkJ0.tif*
# * *gs://open-buildings-temporal-data/v1/geotiffs/3be7c_2023_06_30/tile_ZJUo2y3Nj6s.tif*
# * *gs://open-buildings-temporal-data/v1/geotiffs/3be7c_2023_06_30/tile_y0RJ1TudVeQ.tif*
#
# The next cells will ask where to download the tifs and where the .txt file containing the URL from google colab is located.

# %%
messagebox.showinfo('Open Buildings Insights', 'Browse to the folder where you want to download the tif files')
download_directory = filedialog.askdirectory()
messagebox.showinfo('Open Buildings Insights', 'Select the .txt you obtained from google colab')
text_file_path= filedialog.askopenfilename()

# %% [markdown]
# The tiff files have the form *tile_uhCUB-kvkJ0.tif*, the next cell allows to personalize based on the area of study. It will take the form of *Bhiwandi_tile_uhCUB-kvkJ0.tif*

# %%
name_region='Bhiwandi'

# %% [markdown]
# The two functions are written to read the .txt containing the url, iterating through each line, establishing a connection to the server, and downloading the information to the folder previously specified.

# %%
# Step 1: Download GeoTIFF files
def download_geotiff(url, output_path):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise exception for HTTP errors
        with open(output_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        #print(f"Downloaded: {output_path}")
    except Exception as e:
        print(f"Error downloading {url}: {e}")

# Step 2: Main process
def process_geotiff_files(download_directory, name_region):

    with open(text_file_path,'r') as url_list:
        for url in url_list:
            filename = url.split('/')[-1]  # Extract the filename from URL
            filename = filename.strip()

            url = url.replace("gs://", "https://storage.googleapis.com/")
            url = url.strip()
             
            local_path = os.path.join(download_directory, name_region+"_"+filename)
             
            # Download the file
            download_geotiff(url, local_path)
      
            print(f"Geotiff downloaded to: {local_path}")

# %%
# Run the script
if __name__ == "__main__":
    process_geotiff_files(download_directory, name_region)

# %%
datetime.now().strftime("%Y-%m-%d %H:%M:%S")
